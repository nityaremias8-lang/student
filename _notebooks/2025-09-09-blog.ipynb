# %% [raw]
# ---
# title: Grade Predictor
# comments: true
# layout: post
# permalink: /nityablog
# description: Nitya's CSP Blog
# author: Nitya Remias
# ---

# %% [markdown]
# ## first day
# - First we downladed VS code, and learned how to use a terminal
# - We learned the key commands: mkdir, cd, pwd, ls
# - I had some problems installing python because the instructions said python, when we were actually supposed to do python3
# - I also cloned the worng directory into mine, so I had to reclone to make sure my respotitory was connected to GitHUB
# - I think it would be good to add a page on brew install and make sure to install wget
# - I am some hiccups because I was not sure what I was doing and why I was doing it
#
# ## Meaning of Commands
# - mkdir: make directory
# - ls: list
# - cd: open
# - pwd: present working directory
#
# ## Things I learned
# - make sure to take notes on everything you do, because it is easy to make a bunch of changes and get lost
# - COMMIT when everything works so that you don't lose what works and make changes and wonder why it doesn't work
