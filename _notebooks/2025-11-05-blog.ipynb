# %% [raw]
# ---
# title: Nitya's Restrospective Blog
# comments: true
# layout: post
# permalink: /retroblog
# description: Nitya's CSP Blog
# author: Nitya Remias
# ---

# %% [markdown]
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>My CSP Journey - Trimester 1</title>
#     <style>
#         * {
#             margin: 0;
#             padding: 0;
#             box-sizing: border-box;
#         }
#  body {
#             font-family: 'Segoe UI', Tahoma, Geneva, Verdana, sans-serif;
#             background: linear-gradient(135deg, #667eea 0%, #764ba2 100%);
#             color: #fff;
#             line-height: 1.6;
#             min-height: 100vh;
#         }
#  .container {
#             max-width: 900px;
#             margin: 0 auto;
#             padding: 40px 20px;
#         }
#  header {
#             text-align: center;
#             margin-bottom: 50px;
#             animation: fadeInDown 1s ease;
#         }
# h1 {
#             font-size: 3em;
#             margin-bottom: 10px;
#             text-shadow: 3px 3px 6px rgba(0,0,0,0.3);
#         }
# .subtitle {
#             font-size: 1.2em;
#             opacity: 0.9;
#         }
#  .section {
#             background: rgba(255, 255, 255, 0.1);
#             backdrop-filter: blur(10px);
#             border-radius: 15px;
#             padding: 30px;
#             margin-bottom: 30px;
#             box-shadow: 0 8px 32px rgba(0,0,0,0.2);
#             animation: fadeInUp 1s ease;
#         }
#  h2 {
#             font-size: 2em;
#             margin-bottom: 20px;
#             border-bottom: 3px solid rgba(255,255,255,0.3);
#             padding-bottom: 10px;
#         }
#  h3 {
#             font-size: 1.5em;
#             margin: 25px 0 15px 0;
#             color: #ffd700;
#         }
#  ul {
#             list-style: none;
#             padding-left: 0;
#         }
# li {
#             padding: 10px 0 10px 30px;
#             position: relative;
#             margin-bottom: 8px;
#         }
#  li:before {
#             content: "→";
#             position: absolute;
#             left: 0;
#             color: #ffd700;
#             font-weight: bold;
#             font-size: 1.2em;
#         }
#          .score-box {
#             background: rgba(255, 215, 0, 0.2);
#             border-left: 4px solid #ffd700;
#             padding: 20px;
#             margin: 20px 0;
#             border-radius: 8px;
#         }
# .question-card {
#             background: rgba(0, 0, 0, 0.2);
#             padding: 15px;
#             margin: 15px 0;
#             border-radius: 8px;
#             border-left: 4px solid #ff6b6b;
#         }
#  .correct-answer {
#             color: #51cf66;
#             font-weight: bold;
#         }
#  .key-concept {
#             background: rgba(81, 207, 102, 0.2);
#             padding: 8px 12px;
#             border-radius: 5px;
#             margin: 8px 0;
#             display: inline-block;
#         }
# @keyframes fadeInDown {
#             from {
#                 opacity: 0;
#                 transform: translateY(-50px);
#             }
#             to {
#                 opacity: 1;
#                 transform: translateY(0);
#             }
#         }
#  @keyframes fadeInUp {
#             from {
#                 opacity: 0;
#                 transform: translateY(50px);
#             }
#             to {
#                 opacity: 1;
#                 transform: translateY(0);
#             }
#         }
#  .highlight {
#             background: rgba(255, 215, 0, 0.3);
#             padding: 2px 6px;
#             border-radius: 3px;
#         }
#
#         .footer {
#             text-align: center;
#             padding: 30px;
#             opacity: 0.8;
#         }
#     </style>
# </head>
# <body>
#     <div class="container">
#         <header>
#             <h1>🚀 My Coding Journey</h1>
#             <p class="subtitle">CSP Trimester 1 </p>
#         </header>
#  <div class="section">
#             <h2>📚 Big Idea 3 Learning Reflections</h2>
#              <h3>3.1 – Variables and Assignments</h3>
#             <ul>
#                 <li>Variables are like containers that hold information I need to use later</li>
#                 <li>Learning to name variables clearly made my code much more readable</li>
#                 <li>I realized how important it is to update variables properly to avoid bugs</li>
#             </ul>
#
#   <h3>3.2 – Data Abstraction and Lists</h3>
#             <ul>
#                 <li>Lists help me organize multiple related items under one name instead of creating tons of separate variables</li>
#                 <li>Understanding indices was tricky at first, but practicing helped me get comfortable with accessing list elements</li>
#                 <li>Data abstraction simplifies complexity, which is exactly what programming should do</li>
#             </ul>
#  <h3>3.3 – Mathematical Expressions and Operators</h3>
#             <ul>
#                 <li>Order of operations (PEMDAS) applies in programming just like in math class</li>
#                 <li>Learned the difference between division operators and how they affect results</li>
#                 <li>Using parentheses strategically helps me control exactly how calculations happen</li>
#             </ul>
#
#  <h3>3.4 – Strings</h3>
#             <ul>
#                 <li>Strings let me manipulate text as easily as I work with numbers</li>
#                 <li>String concatenation and slicing opened up new ways to process text data</li>
#                 <li>Understanding that strings are sequences of characters helped me think about text differently</li>
#             </ul>
#
# <h3>3.5 – Boolean Expressions</h3>
#             <ul>
#                 <li>Boolean logic is the foundation of how programs make decisions</li>
#                 <li>AND, OR, and NOT operators combine to create complex conditions</li>
#                 <li>Practicing truth tables helped me predict outcomes before running code</li>
#             </ul>
#
# <h3>3.6 – Conditionals</h3>
#             <ul>
#                 <li>If-else statements give programs the power to respond differently based on conditions</li>
#                 <li>Learning the syntax differences between Python (elif) and JavaScript (else if) was important for working in both languages</li>
#                 <li>Proper indentation in Python became second nature after writing enough conditionals</li>
#             </ul>
#
# <h3>3.7 – Nested Conditionals</h3>
#             <ul>
#                 <li>Nesting conditionals lets me create more sophisticated decision-making logic</li>
#                 <li>I learned to be careful about indentation and structure to avoid confusing myself</li>
#                 <li>Breaking down complex logic into smaller pieces made nested conditionals easier to understand</li>
#             </ul>
#
#  <h3>3.8 – Iteration</h3>
#             <ul>
#                 <li>Loops save me from writing repetitive code by automating repeated tasks</li>
#                 <li>For loops and while loops serve different purposes, and choosing the right one matters</li>
#                 <li>Understanding loop counters and how they increment helped me avoid infinite loops</li>
#             </ul>
#
# <h3>3.9 – Algorithms</h3>
#             <ul>
#                 <li>Algorithms are step-by-step procedures for solving problems</li>
#                 <li>Every algorithm takes input, processes it, and produces output</li>
#                 <li>Learning to think algorithmically improved my problem-solving approach overall</li>
#             </ul>
#
# <h3>3.10 – Lists</h3>
#             <ul>
#                 <li>Lists can hold any type of data and are incredibly versatile</li>
#                 <li>Practiced adding, removing, and modifying list elements efficiently</li>
#                 <li>The popcorn hacks really solidified my understanding through hands-on practice</li>
#             </ul>
#
# <h3>3.12 – Procedures</h3>
#             <ul>
#                 <li>Procedures (functions) let me reuse code instead of copying and pasting</li>
#                 <li>Writing procedures makes debugging easier since I only fix code in one place</li>
#                 <li>Learning when to create a procedure versus writing inline code improved my code organization</li>
#             </ul>
#
# <h3>3.13 & 3.15 – Random Values</h3>
#             <ul>
#                 <li>Random functions add unpredictability to programs, making them more dynamic</li>
#                 <li>Used randomness to simulate real-world scenarios like dice rolls or shuffling</li>
#                 <li>Understanding how to control the range of random values gave me more flexibility</li>
#             </ul>
#
#   <h3>3.17 – Algorithmic Efficiency</h3>
#             <ul>
#                 <li>Not all solutions are equal – some algorithms run much faster than others</li>
#                 <li>Learned to think about time complexity and why it matters for large datasets</li>
#                 <li>Optimizing code isn't just about getting the right answer, but getting it efficiently</li>
#             </ul>
#         </div>
#
#  <div class="section">
#             <h2>🌟 Growth and Transformation</h2>
#             <ul>
#                 <li>At the start of the year, code looked like a foreign language that I'd never understand</li>
#                 <li>Now I can read code and understand what it's doing, even debug it when things go wrong</li>
#                 <li>My confidence has grown tremendously – I'm no longer afraid to try new approaches</li>
#                 <li>I've learned that mistakes are valuable learning opportunities, not failures</li>
#                 <li>Problem-solving has become more intuitive; I think in terms of algorithms now</li>
#                 <li>Working as part of a team taught me communication and collaboration skills I didn't have before</li>
#             </ul>
#         </div>
#
# <div class="section">
#     <h2>🛠️ Key Learning from Early Sprints</h2>
#
#  <h3>Tools Sprint</h3>
#             <ul>
#                 <li>Mastered essential tools like Git, VSCode, and terminal commands</li>
#                 <li>Understanding localhost servers and how to run projects locally was a game-changer</li>
#                 <li>Commands like cd, git clone, and git push became part of my daily workflow</li>
#                 <li>These foundational tools made everything else possible</li>
#             </ul>
#
# <h3>JavaScript and Python Fundamentals</h3>
#             <ul>
#                 <li>Learned the syntax and structure of two powerful programming languages</li>
#                 <li>Switching between JavaScript and Python helped me understand programming concepts independent of language</li>
#                 <li>Each language has its strengths – JavaScript for web, Python for simplicity and data</li>
#                 <li>Became comfortable reading documentation and applying it to solve problems</li>
#             </ul>
#
#  <h3>West Coast Travel Project</h3>
#             <ul>
#                 <li>This project was where creativity met code, and I loved every minute</li>
#                 <li>Learned to think about user experience and how design choices affect engagement</li>
#                 <li>Implemented features like progress bars, interactive buttons, and audio elements</li>
#                 <li>Troubleshooting issues as a team taught me the value of collaborative problem-solving</li>
#                 <li>Seeing my design come to life was incredibly rewarding and motivating</li>
#                 <li>This was the most creative sprint and my personal favorite overall.</li>
#                 <li>Although our class fell slightly behind during the first few days of planning, we persevered by holding multiple class meetings filled with passionate discussion.</li>
#                 <li>I enjoyed seeing everyone pitch in their ideas, the discussions that ensued, and coming up with a great overall idea: a road trip.</li>
#                 <li>I loved designing the <strong>Travel Module</strong> within the <em>West Coast Travel Quest</em> project — a virtual road trip up the West Coast where I applied everything I’d learned to build an interactive user interface.</li>
#                 <li>I combined coding with creativity by integrating progress bars, buttons, hierarchy, and audio.</li>
#                 <li>While coding the module, we ran into issues with local storage integration, but after a 2-hour <strong>Cool Collaborators</strong> team meeting, we solved it!</li>
#                 <li>This sprint helped me see how programming connects to real-world design and how front-end coding can make information both useful and beautiful.</li>
#             </ul>
#         </div>
#
#  <div class="section">
#             <h2>🎭 Night at the Museum</h2>
#             <ul>
#                 <li>Presenting my work to visitors gave me a sense of accomplishment I hadn't expected</li>
#                 <li>I liked the comments that complemented the aesthetic and visuals of our modules and the ones that commented on local storage</li>
#                 <li>Explaining technical concepts to non-programmers helped me understand the material even better</li>
#                 <li>Positive feedback from others validated all the hard work I'd put in</li>
#                 <li>Sharing my project with family and friends made the learning feel more real and meaningful</li>
#                 <li>The event showed me that what I'm learning has real-world value</li>
#             </ul>
#         </div>
#
#  <div class="photo-grid">
#         <img class="photo" src="./_notebooks_/IMG_7598_2.jpg" alt="N@M">
#         <img class="photo" src="./_notebooks_/IMG_7606.jpeg" alt="N@M">
#       </div>
# <meta charset="UTF-8">
# <meta name="viewport" content="width=device-width, initial-scale=1.0">
# <title>Image Slider</title>
# <style>
#   * {
#     box-sizing: border-box;
#   }
#
#   body {
#     font-family: Arial, sans-serif;
#     background-color: #f8f8f8;
#     text-align: center;
#   }
#
#   .slider {
#     position: relative;
#     max-width: 600px;
#     margin: 40px auto;
#     border-radius: 10px;
#     overflow: hidden;
#     box-shadow: 0 0 10px rgba(0,0,0,0.3);
#   }
#
#   .slides {
#     display: flex;
#     transition: transform 0.5s ease-in-out;
#   }
#
#   .slides img {
#     width: 100%;
#     border-radius: 10px;
#   }
#
#   .arrow {
#     position: absolute;
#     top: 50%;
#     transform: translateY(-50%);
#     font-size: 30px;
#     color: white;
#     background-color: rgba(0,0,0,0.4);
#     padding: 10px;
#     border-radius: 50%;
#     cursor: pointer;
#     user-select: none;
#   }
#
#   .arrow:hover {
#     background-color: rgba(0,0,0,0.7);
#   }
#
#   .prev {
#     left: 15px;
#   }
#
#   .next {
#     right: 15px;
#   }
# </style>
# <script>
#   let index = 0;
#
#   function moveSlide(direction) {
#     const slides = document.querySelector('.slides');
#     const totalSlides = slides.children.length;
#
#     index = (index + direction + totalSlides) % totalSlides;
#     slides.style.transform = `translateX(${-index * 100}%)`;
#   }
# </script>
#
# <div class="section">
#             <h2>🎯 What's Next?</h2>
#             <ul>
#                 <li>I want to dive deeper into data science and learn how to extract insights from data</li>
#                 <li>Exploring visualization libraries will help me present data in compelling ways</li>
#                 <li>Learning about machine learning basics would be an exciting next challenge</li>
#                 <li>I'm interested in building more complex applications that solve real problems</li>
#                 <li>Want to continue improving my algorithmic thinking and efficiency</li>
#             </ul>
#         </div>
#
#  <div class="section">
#             <h2>📊 66 Question MC Review</h2>
#
#  <div class="score-box">
#                 <h3>Overall Performance: 49/66 (72.7%)</h3>
#             </div>
#
# <div class="question-card">
#                 <strong>Q13 – Social Media Data Analysis</strong>
#                 <p>Your Answer: A | <span class="correct-answer">Correct: D</span></p>
#                 <p><span class="key-concept">Key Concept:</span> Compare data trends before and after significant milestones</p>
#                 <ul>
#                     <li>Need to analyze average message length pre/post mobile app release</li>
#                     <li>Look for patterns that emerge after key events in the timeline</li>
#                 </ul>
#             </div>
#
#  <div class="question-card">
#                 <strong>Q14 – Comparing Loop Algorithms</strong>
#                 <p>Your Answer: D | <span class="correct-answer">Correct: C</span></p>
#                 <p><span class="key-concept">Key Concept:</span> Display timing (before vs after increment) affects output</p>
#                 <ul>
#                     <li>Both programs display the same number of values, but values differ by 1</li>
#                     <li>Must trace through each iteration carefully to see when display occurs</li>
#                 </ul>
#             </div>
#
# <div class="question-card">
#                 <strong>Q26 – Robot Navigation with Conditionals</strong>
#                 <p>Your Answer: C | <span class="correct-answer">Correct: B</span></p>
#                 <p><span class="key-concept">Key Concept:</span> Trace robot movements step by step on the grid</p>
#                 <ul>
#                     <li>Conditional moves depend on CAN_MOVE checking for obstacles</li>
#                     <li>Must simulate the robot's path through IF/ELSE logic to verify correct movement</li>
#                 </ul>
#             </div>
# <div class="question-card">
#                 <strong>Q30 – Video Streaming Database Analysis</strong>
#                 <p>Your Answer: D | <span class="correct-answer">Correct: D (5 hours)</span></p>
#                 <p><span class="key-concept">Key Concept:</span> Count all procedure calls to calculate total runtime</p>
#                 <ul>
#                     <li>NumViewers is called once before the loop + 4 times in the loop = 5 total</li>
#                     <li>Each call takes 1 hour, so total time is 5 hours</li>
#                 </ul>
#             </div>
#  <div class="question-card">
#                 <strong>Q37 – Computing Average from List</strong>
#                 <p>Your Answer: D | <span class="correct-answer">Correct: C</span></p>
#                 <p><span class="key-concept">Key Concept:</span> Both display correct average, but efficiency differs</p>
#                 <ul>
#                     <li>Code segment I performs numList/LENGTH(numList) inside the loop (inefficient)</li>
#                     <li>Code segment II performs this operation once after the loop (efficient)</li>
#                 </ul>
#             </div>
#  <div class="question-card">
#                 <strong>Q40 – Exam Score Replacement Analysis</strong>
#                 <p>Your Answer: B | <span class="correct-answer">Correct: D</span></p>
#                 <p><span class="key-concept">Key Concept:</span> All three statistics can be determined from the data</p>
#                 <ul>
#                     <li>I. Average total points: YES (from total points calculation)</li>
#                     <li>II. Average increase: YES (compare before/after policy)</li>
#                     <li>III. Proportion improved: YES (compare midterm vs final to total points)</li>
#                 </ul>
#             </div>
# <div class="question-card">
#                 <strong>Q42 – IPv4 vs IPv6 Address Space</strong>
#                 <p>Your Answer: C | <span class="correct-answer">Correct: D</span></p>
#                 <p><span class="key-concept">Key Concept:</span> Exponential growth in address space</p>
#                 <ul>
#                     <li>IPv6 has 2^96 times as many addresses as IPv4, not 2^4</li>
#                     <li>128 bits - 32 bits = 96 bit difference = 2^96 multiplier</li>
#                 </ul>
#             </div>
#  <div class="question-card">
#                 <strong>Q43 – Algorithm Runtime Analysis</strong>
#                 <p>Your Answer: B | <span class="correct-answer">Correct: A</span></p>
#                 <p><span class="key-concept">Key Concept:</span> Polynomial runtime is considered reasonable</p>
#                 <ul>
#                     <li>Pattern shows n² growth, which is polynomial</li>
#                     <li>Polynomial algorithms run in reasonable time, unlike exponential</li>
#                 </ul>
#             </div>
#
# <div class="question-card">
#                 <strong>Q44 – 4-bit Integer Overflow</strong>
#                 <p>Your Answer: C | <span class="correct-answer">Correct: B</span></p>
#                 <p><span class="key-concept">Key Concept:</span> 4 bits can represent 0-15; >15 causes overflow</p>
#                 <ul>
#                     <li>Only 14 + 5 = 19 exceeds maximum value of 15</li>
#                     <li>7 + 7 = 14 and 14 - 15 = -1 both fit within range</li>
#                 </ul>
#             </div>
#  <div class="question-card">
#                 <strong>Q48 – Simulation with Random Values</strong>
#                 <p>Your Answer: B | <span class="correct-answer">Correct: D</span></p>
#                 <p><span class="key-concept">Key Concept:</span> 75% success means random value should be ≤ 0.75</p>
#                 <ul>
#                     <li>RANDOM(0,1) ≤ 0.75 gives 75% probability of success</li>
#                     <li>Must match the probability to the condition correctly</li>
#                 </ul>
#             </div>
#
# <div class="question-card">
#                 <strong>Q63 – Counting Prime Numbers</strong>
#                 <p>Your Answer: C | <span class="correct-answer">Correct: B & D</span></p>
#                 <p><span class="key-concept">Key Concept:</span> Count should accumulate, not reset</p>
#                 <ul>
#                     <li>Remove line 4 (count ← 0) – shouldn't reset count in loop</li>
#                     <li>Remove line 9 (count ← count + 1 outside IF) – only increment for primes</li>
#                 </ul>
#             </div>
#  <div class="question-card">
#                 <strong>Q65 – Multiply Procedure Error</strong>
#                 <p>Your Answer: C | <span class="correct-answer">Correct: B & C</span></p>
#                 <p><span class="key-concept">Key Concept:</span> Loop fails when y is negative</p>
#                 <ul>
#                     <li>Condition count = y never met if y < 0 (count starts at 0 and increases)</li>
#                     <li>Works when y is positive, fails when y is negative</li>
#                 </ul>
#             </div>
# <div class="question-card">
#                 <strong>Q66 – Finding Smallest Value in List</strong>
#                 <p>Your Answer: C | <span class="correct-answer">Correct: C & D</span></p>
#                 <p><span class="key-concept">Key Concept:</span> Must scan entire list before returning</p>
#                 <ul>
#                     <li>Returns first value smaller than first element, not overall minimum</li>
#                     <li>Fails when minimum value appears at the end of the list</li>
#                 </ul>
#             </div>
#         </div>
#  <div class="section">
#             <h2>💭 Final Reflections</h2>
#             <ul>
#                 <li>This trimester pushed me out of my comfort zone in the best way possible</li>
#                 <li>I learned that programming is as much about persistence as it is about logic</li>
#                 <li>My teammates made challenging moments enjoyable and frustrating bugs easier to fix</li>
#                 <li>I'm grateful for mentors who helped me when I felt stuck</li>
#                 <li>Looking back, I've grown more than I thought possible in just one trimester</li>
#                 <li>Excited to continue this journey and see where coding takes me next</li>
#             </ul>
#         </div>
#
#  <div class="footer">
#             <p>✨ End of Trimester 1 - Onward to New Adventures! ✨</p>
#         </div>
