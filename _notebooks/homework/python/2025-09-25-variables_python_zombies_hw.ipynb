# %% [raw]
# ---
# layout: post
# title: Variables & Assignments
# description: This page will provide homework for the variables and assigmnets lesson.
# permalink: /python/variables/zombies/hw
# breadcrumb: True
# Author: Ethan Patel, Tanay Paranjpe, Neil Manjrekar
# ---

# %% [markdown]
# ## Variables & Assignment Homework
# ---
# Description:
# - In this homework hack, you will practice creating and using variables. You’ll define variables to store your name and age, reassign values, and answer interactive questions to test your understanding. This activity will help you master the basics of variables and how they work in programming.

# %% [markdown]
# # 🏠 Variables Quest Homework
#
# **Objective:** Practice creating, manipulating, and combining strings in Python.
#
# ---
#
# ## Instructions
#
# Complete each challenge by **filling in the missing code**. Use the examples as a guide, but make sure to write your own values or logic.

# %% [markdown]
# ## Challenge 1: Creating a Life Profile with Variables

# %%
# Part 1
## Personal info
my_name = "Nitya"           # Fill in your name
my_age = 17                 # Fill in your age
my_city = "SanDiego"        # Fill in the city where you live

# Part 2
## Preferences
favorite_color = "purple"    # Your favorite color
favorite_food = "sushi"      # Your favorite food
favorite_movie = "none"      # Your favorite movie
favorite_song = "silverlining"  # Your favorite song

# Part 3
# Reassign some variables
favorite_food = "purple"    # Seems intentional, but note this overwrites favorite_food
my_city = "sandiego"        # Note the lowercase 's' here
has_pet = True

# Additional variables to avoid errors in printing
is_student = True
is_online = False
likes_music = True

# Part 5: Print Your Life Profile
print("Name:", my_name)
print("Age:", my_age)
print("City:", my_city)
print("Favorite color:", favorite_color)
print("Favorite food:", favorite_food)
print("Favorite movie:", favorite_movie)
print("Favorite song:", favorite_song)
print("Student?", is_student)
print("Has pet?", has_pet)
print("Online?", is_online)
print("Likes music?", likes_music)
# Out:
# Name: Nitya
# Age: 17
# City: sandiego
# Favorite color: purple
# Favorite food: purple
# Favorite movie: none
# Favorite song: silverlining
# Student? True
# Has pet? True
# Online? False
# Likes music? True

# %% [markdown]
# # Task 2

# %% [markdown]
# ## Creative Challenge
#
# Your task: Create a “story” or “profile” using **ONLY variables and assignments**.
#
#
# ### Instructions:
#
# 1. **Create at least 8 variables** to describe a character or yourself.
#    Examples:
#    `name`, `age`, `favorite_food`, `hobby`, `number_of_pets`, `mood`, `favorite_color`, `dream_job`
#
# 2. **Assign initial values** to all variables.
#
# 3. **Reassign at least 4 of the variables** to new values to simulate changes over time or “events” in the story.
#
# 4. Use **print statements** to write a story or profile that is **at least 5 sentences long**.
#    Each sentence should include at least one variable.
#    Example:
#    > "Tanay ('age' 17) loves pizza and plays tennis ('hobby') every weekend. Today, Tanay is happy because he ate his ('favoirite_food')."
#
# 5. Optional: Add **extra variables** to make your story longer and more creative.
#    You can also create “day 2”, “day 3”, etc., by reassigning variables and printing new sentences.
#
# ### Goal:
#
# - Show creativity while practicing:
#   - Variable creation
#   - Variable reassignment
#   - Using variables in print statements
#   - Experiment with assigment and reassigment to update variables

# %%
# Step 1 & 2: Create variables and assign initial values
name = "Nitya"
age = 17
favorite_food = "sushi"
hobby = "swimming"
number_of_pets = 1
mood = "calm"
favorite_color = "purple"
dream_job = "lawyer"

# Step 3: Reassign some variables to simulate changes or events
age = 18                        # A year has passed
number_of_pets = 2              # I adopted another pet
mood = "excited"                
dream_job = "chef"   # Dream job evolved

# Step 4: Print a story using these variables
print(f"{name} is {age} years old and loves {favorite_food}.")
print(f"One of {name}'s favorite pastimes is {hobby}, especially on rainy days.")
print(f"Recently, {name} adopted a second pet, so now there are {number_of_pets} pets at home.")
print(f"Today, {name} feels very {mood} because {name}'s dream job changed to becoming a {dream_job}.")
print(f"Despite all the changes, {favorite_color} remains {name}'s favorite color and a source of inspiration.")
# Out:
# Nitya is 18 years old and loves sushi.
# One of Nitya's favorite pastimes is swimming, especially on rainy days.
# Recently, Nitya adopted a second pet, so now there are 2 pets at home.
# Today, Nitya feels very excited because Nitya's dream job changed to becoming a chef.
# Despite all the changes, purple remains Nitya's favorite color and a source of inspiration.
